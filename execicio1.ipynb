# %%
import pandas as pd
import matplotlib.pyplot as plt

# criando um mini conjunto de dados 
dados = {'Mês':['jan', 'fev', 'mar'],
'Vendas': [100, 150, 120]}
df = pd.DataFrame(dados)

# Criando um gráfico rápido
df.plot(x='Mês', y='Vendas', kind='bar')
plt.show()
